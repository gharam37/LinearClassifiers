# %%
import numpy as np
import matplotlib.pyplot as plt
my_img = plt.imread('Train/1.jpg')
ImagesArray=[]
targetArray=[]
baseTarget=(np.ones((1,2400)))[0]

baseNegative=(np.ones((1,240)))[0]

c0=(np.ones((1,2400)))[0]

c1=(np.ones((1,2400)))[0]
c2=(np.ones((1,2400)))[0]
c3=(np.ones((1,2400)))[0]
c4=(np.ones((1,2400)))[0]
c5=(np.ones((1,2400)))[0]
c6=(np.ones((1,2400)))[0]
c7=(np.ones((1,2400)))[0]
c8=(np.ones((1,2400)))[0]
c9=(np.ones((1,2400)))[0]







for i in range(0,len(c0)):
    if not(i>=0 and i<=240):
        c0[i]=-1;
        
for i in range(0,len(c1)):
    if not(i>=241 and i<=240*2):
        c1[i]=-1;
for i in range(0,len(c1)):
    if not(i>240*2 and i<=240*3):
        c2[i]=-1;
        
        
for i in range(0,len(c1)):
    if not(i>240*3 and i<=240*4):
        c3[i]=-1;
        
        
for i in range(0,len(c1)):
    if not(i>240*4 and i<=240*5):
        c4[i]=-1;
        
        
for i in range(0,len(c1)):
    if not(i>240*5 and i<=240*6):
        c5[i]=-1;
        
        
for i in range(0,len(c1)):
    if not(i>240*7 and i<=240*8):
        c6[i]=-1;
for i in range(0,len(c1)):
    if not(i>240*8 and i<=240*9):
        c7[i]=-1;
        
for i in range(0,len(c1)):
    if not(i>240*8 and i<=240*9):
        c8[i]=-1;
for i in range(0,len(c1)):
    if not(i>240*9 and i<=240*100):
        c9[i]=-1;



for i in range (1,2401):
    Image=plt.imread('Train/'+str(i)+'.jpg')
    Image=np.asarray(Image)  
    Image= np.asmatrix(Image)
    #Image=np.reshape(Image, (1,784))
    #Image=Image[0]
    #print(len(Image))
    #print(Image)
    ImagesArray =ImagesArray+[Image]
        
x=np.asarray(ImagesArray)  
#print(x[0])
xtranspose=x.transpose()
print(np.info(xtranspose))
#print(np.info(x))

mult=np.dot(x, xtranspose)
print(np.info(mult))
inverse=np.linalg.pinv(mult)
print(np.info(inverse))

Factor=np.dot(xtranspose,inverse)

w0=np.dot(Factor,c0)
w1=np.dot(Factor,c1)
w2=np.dot(Factor,c2)
w3=np.dot(Factor,c3)
w4=np.dot(Factor,c4)
w5=np.dot(Factor,c5)
w6=np.dot(Factor,c6)
w7=np.dot(Factor,c7)
w8=np.dot(Factor,c8)
w9=np.dot(Factor,c9)
print("Weight")
print(w9)
weights=[w0,w1,w2,w3,w4,w5,w6,w7,w8,w9]
testArray=[]
for i in range (1,201):
    Image=plt.imread('train/'+str(i)+'.jpg')
    Image=np.asarray(Image)     
    Image=np.reshape(Image, (1,784))
    Image=Image[0]
    testArray =testArray+[Image]

    

for i in range(0,200):
    image0=testArray[i]
    output=np.dot(weights[0],image0)
    c=0;
    for j in range(0,len(weights)):
        output2=np.dot(weights[j],image0)
        #print(output2)
        if output2>output:
            output=output2;
            #print("Here")
            c=j
    print(c)
    

#print(len(targetArray))
#print(len(plt.imread('Train/'+str(1)+'.jpg')))
# Out:
# class:  ndarray
# shape:  (28, 28, 2400)
# strides:  (1, 28, 784)
# itemsize:  1
# aligned:  True
# contiguous:  False
# fortran:  True
# data pointer: 0x2ae0010b040
# byteorder:  little
# byteswap:  False
# type: uint8
# None
# class:  ndarray
# shape:  (2400, 28, 28, 2400)
# strides:  (1881600, 67200, 2400, 1)
# itemsize:  1
# aligned:  True
# contiguous:  True
# fortran:  False
# data pointer: 0x2ae7fc9d040
# byteorder:  little
# byteswap:  False
# type: uint8
# None
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-6-d63464f1b1ce> in <module>
#      86 mult=np.dot(x, xtranspose)
#      87 print(np.info(mult))
# ---> 88 inverse=np.linalg.pinv(mult)
#      89 print(np.info(inverse))
#      90
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\linalg\linalg.py in pinv(a, rcond)
#    1936         return wrap(res)
#    1937     a = a.conjugate()
# -> 1938     u, s, vt = svd(a, full_matrices=False)
#    1939
#    1940     # discard small singular values
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\linalg\linalg.py in svd(a, full_matrices, compute_uv)
#    1610
#    1611         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1612         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1613         u = u.astype(result_t, copy=False)
#    1614         s = s.astype(_realType(result_t), copy=False)
#
# MemoryError:
